# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import sklearn
from utils import _ohlc,df_filter_times,filter_name_date, showOHLC
from sklearn.cluster import KMeans

from matplotlib import pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
df_all = pd.read_csv("./data/1m-10d.csv",parse_dates=["datetime"])
df_market = df_filter_times(df_all)
df_value = df_market.groupby("name")['close'].mean()

# %%
df = filter_name_date(df_market, "ADBE", "2024-4-15")
# Out:
# Available dates
# 2024-04-08
# 2024-04-09
# 2024-04-10
# 2024-04-11
# 2024-04-12
# 2024-04-15
# 2024-04-16
# 2024-04-17
# 2024-04-18
# 2024-04-19

# %%
showOHLC(df)
